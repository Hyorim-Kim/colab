# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyorim-Kim/numpi/blob/main/tfc30character.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 글자 수준의 LSTM 텍스트 생성 모델 구현 - 니체의 글
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

# path = keras.utils.get_file(
#     'rnn_short_toji.txt',
#     origin='https://github.com/pykwon/etc/blob/master/rnn_short_toji.txt')
# text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://github.com/pykwon/etc/blob/master/rnn_short_toji.txt
#    8192/Unknown - 0s 0us/step말뭉치 크기: 532322

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 177421
# 고유한 글자: 1555
# 벡터화...
# <ipython-input-2-d455523679f3>:26: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-2-d455523679f3>:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars)), activation='tanh'))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               95232
#
#  dense (Dense)               (None, 57)                7353
#
# =================================================================
# Total params: 102585 (400.72 KB)
# Trainable params: 102585 (400.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
def sample(preds, temperature=1.0):  # temperature로 확률 분포의 가중치를 조정
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 16s 6ms/step - loss: 2.0263
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the conccined to the pricies of the such and the souls and seess of the fact the ward to the men to the precisely the sees and the men to the presenter and still the presentication, and the manical and the sould the manication of the believes in the manical to the such and the manical to the presenter and the proper and the presenter and the fact the same the sees and the manical to the fact of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the instinct of child to light, belief in the men of iness concention of the believer and all experion, and should and the songing to man and seinct of the most and propasing and manication in the seined hister and the possiblicies, and the allest of such the fact from the precess of the world the nother of the precise of the seection, of son say, the senting to the matical conclise to the there
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forth soce has car of the speeelt be no spenite, histing which the intjuse esplating, ever thisg, is the sing it of concciousteable of concurartion, of the acthice, the seist.--
# hi, he nownheus where
# bein
# any is mayth to mini: of which pribers and maming0. to
# thende wation so
# cakepo shomed to think no are the gnetemetias of eniginesion to greeagorande, asain, in at entralitys, they one that which th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forn and into
# luthoule colagice
# so it heurd ywane'y see toulk of buck-provficiomoms with, formaratho beinger starnauc8ly a
# neilorr, endects they is smindw calupisery, ristenes and dustwice misinnef"e tyst good conccrasi) cinnecss--abeilignoww char. ho stirdl
# thause and suy froll. negwer somethoms abvodial coppuride-7ans reise,
# every foulxtives tenbiblidiance. andest
# of "workentay tren,taclers,
# man6w
# 에포크 2
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.6410
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for a same the same a desires and the strongle of the possible and do not the same the self--a dead the reason and all the same the same the consequently the stronger the self--a same a something to the belief the same the same a something of the most man in the be for a say to be the will in the same the same the stronger and the has the be a same the still the relation of the same the same to the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the seaven of they to fain a as a serves a seem as the same themselves of
# the same fain, for a man of the profound so the former for a many our still a deligious of the the problem of corvest of the fairly of the same the same a distones. to have the same expeciation. by the string--father of the profound of the profound and a say, for sank to be its religion and a sertime of the will be not has
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for a protuper to in
# the most also a suckemed," "inventing and weaker, and dost in
# cancuquer
# "laves of
# micuriried of the perpect of himse who persapisivey and gramper of may in himself one and bood" as wheithed by conserves. what fertinames and femi one invery to it
# is mantal are,
# as them
# doced new
# the ireabol have siftion.
#
# i.. he sam, out.
#
#
#
#
# yt
# underenes to the  lourd as borm" beifien shart, cou
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for man you caurence.
#
# 12] wild, faidgen
# dop? or now phild badwith, whe hanthe, ruture--orificared: wherevelen-sonly. to one 1esomether will perit to kind to if men not sit it weave to
# gever: down, fiondly imparsly, somctije, 1ut. he thereptery, vared estreehantly yoe floor to there now havouthe spiris or to
# dies in arried,
# with. for the fach
# ourselves or which to bit intendenge.--natule by on-him e
# 에포크 3
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.5357
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the sense of the condition of the same the state of the condition of the same the condition of the condition of the same the soul and man any sense of the conscience of the stands of the conscience of the suble the good of the same the condition of the condition of the conscience of the condition of the condition of the conscience and the distone and the sings of the condition of the sa
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for saint to be stone probeed of salvation to almost has the condition in the experiations, and son that for a man any more indigness for the sarround of the responsible of the same to incentaristian to the transfations of the has the connounce of the oncingering the interent also it is soul the inclising those be not a means of the germanted that they for the faith of the tants is an them also in t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for calted
# to be specially attodious calmende concemiais of -they whom tractic but sochance in neccantard
# but, rang," only inclease that the i can such an aslighing swoula have gensers of leabions to he is not pution to worthered to senful, to for self-way stron extenlings anyse? a , i
# his own for the true proton with;
# these point
# and is good untouth, it is dwand they art, that into
# it is edonce
# gho
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forermingalias
# its knoch justical dme not only to sen incrisiffes. to gy, they teflotor epparyant antito stands, known, itful
# in hence considfrity owmy seriinrs for it to anstroted he there is
# notiman put to opposing
# blitte, han quient
# sudders inarm else woind.
# for a tr spoms posienties, conside uriturly, rationalick sorme" of goonw entire senstadmic
# spirit orcy, alosifies and latk to
# differences.
#
#
# 에포크 4
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.4833
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the sense of the sense of the most men and the present and the sense of the sense of the sense of the sense of the most men and seems to the belief and the still the men and in the desires of the new and the still the present and self-mestic the men and also the contempt of the most means of the sense of the present and the greatest of the still the standard to the cons
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forming men in self-mensi(nwance of such a metaphysical belief to have all the period of the lack of them and best be the intellect to the truth of the self-more of the maid to discovered in the other and improve of the best the sense of the present of the feels and imperfical into an an artists in to sense of the seek of the superit and all them all the freedom of the concerning and such a man in t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for its overecs of the there shant mooes almovess.= and etticismed thingss on
# themses might in it to traither le existence, as it is atz; or to a worshing
# and plenoton
# in eberome, to itstic of the senstability of the
# comperable to depthe usic fricksancrused beaks rachers. with the contempt areotinase mysting it is not the carlings profound able these found one thereby tever, languantly old we sought
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through founds must that elceal--the conditiou of
# old all
# absuld as it is tas i force
# his good actualge, which has
# not? only earxadmlys out! a one cheldvidious, is not, enough tis
# our concern of cop"pdiescious when faund, upon piodatic all the beain and aknous-and ordinaryonile, sensomed"--pervasiage will cleastly
# differistens matteria man only,"--attenle: and not, theoech, onlismance in
# oken to than sy:ve
# 에포크 5
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.4476
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense the perhaps and for the desire the same the fact the sense the same the same the presence of the sense and for the same and sense of the more pressing the deceating the conduct of the presence of the desire the fact the sense the stronger and the sense the desire the contempt of the sense the from the soul as a conscience of the exceptions of the desire the sense of the sense of the se
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the way can contemptions to the distactions, it is a percietes of the moral man and responsible to the fore the reason of the soul it wagned princifice of the reason in the deceace of the deceavarity of the belief in the standation of the reality of the forming and fortest and beings and betrayed to be and spirits and the good the sense as its opinion, and indificence, and the right to precition
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former
# sprestry light, evens,
# ascioniniess-desired
# by the
# sar, has
# alson sentifuan, which is order to made any, as a debeialy they have noticismatic itself. it is conduction of which our vore specking these ocistumiemance the timntile and
# are nothing is theirbecomeste souther brough proh them is natrely effect
# at a matalism,--powerful and poytomure that their perbe] the
# feclation of extramance of pl
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fode! eye that his worstical cursied wane, which even him this
# antou atcetion toor this took best convictive dream, for from sy
#
# up? two:
# the
# equality, and
# upon ichation ofledive of the goars, the god it
# hearture
# that undernecimance;?--the adsults follessy
# ething of denyers circing itcishe-ofecter ifualled as the injusticagit amobart ta
# moterum, ourseary, upmisuplusionable coffeity, womans, or ye bs
# 에포크 6
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4227
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the fact of the fact of the same the person of the same the sense of the same and the soul he so the sense of the fact the antained and in the same the sense of the soul and the same and that the sense of the sense of the same the sense of the antained the soul and the sense of the same and soul and the soul and the soul and the soul and and souls that the same the states of the mor
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the future that the far a hardly desire understandity in the "fact of the progerming says the more and "sense impossess in all antither and life the seen of the states of the according to the pretended and in still lives in the place and more and that he have no not really an every things of the deeperates the sense and impulse in the one of the free spirit and constants to a volition, and call
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fornels excetpances, noning itself "someth of the sense? image of wet objects of the haritally, hyman law; he own languagre the todiest arizewistes, with fireth imperation) to
# absolute birr, even at gele of "munary and with the most good as arowness somehows and antan examply, is refect, navele, dengers, was that sysce intolle and this equal and supexitied,
# with the tante.
# chermfor this one asours
# w
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for in an exil"ness of all less dungety
# the sourher as impleined confess may duefted tre-prices, thou thew be wan ofren, ue
# rimftled; a hither capacrivi=g and hell elway
# utually and say--this complanshe s old
# afterpy refineded--without us usone
#
# suaccnic . the valued the free men in explasited puoil expeises nome,atencism?. and laborably, this implutual-horisiasn a
# realle at quett goodves uthisy--na
# 에포크 7
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.4052
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through force of the morality of the considere of the sense of the object of the strength of the specially and all the predects of the great and self-decestomed for a suncerning the fact of the considere of the existed and the fact the considere of the world and the self-desire all the considere of the same the sense of the sense of the sense of the considere of the hardly and man and precisely and even and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former with a most an as the interpretation of man.--and the interpretations of the easied and as the feelings of the fact the anyone of the world be every really and the distrust for the world noble and his to all at it is not learn be also let us in the same have feelings of the permect has always become a fear of the successful there is a commands of the see of the soul, and of confurner in which
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fourways disguise, thereby--"christians most disgir more partytors of the mour, the de grobleled
# endly .of
# the hitherto pleast as up jeps and will, the founders outchidess, force, to undergoding and powerful, in the that
# god-goes.
#
#
# coll becauses force finding of blain and was efveolinss as ëulce, for
# remass as a divined it is not food itself
# here he maintaining-
# namely them had becaules of loved pi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through former ichesobl9ed a peotives aprictuigm; them point and tike the necessito to sborch are gavelossges
# suchatation of the will
# of one inrencelons fore of philosophy to hardly
# distinguine, oy
# sugize to langurquals--as amwarrs and cause as was christian mind that on thus knower--laddeurs;--for the here[yed good if eurseelh re7ulp anying adeptionful, thingst unprectinlers, incen.
# inlest orpquilate that
#
# 에포크 8
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3896
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same the strength, and the strength and conscience, and all the same the europe, and the strength and in the same the sense of the same to the same the self-concerning the same to the strength and case that the concealed the strength and conscience, and conscience, and the same the strength and soul, and all the same the existence of the strength and sense to the same to be the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the condition as for the simple of the conduct the soul, i cate here it is weaker in the same to the soul, the instinct, with the world of the reality and always here in the salvation of a
# commander, the ears it is not the called to the "cared the other all the clearly. the store and are epicurear and sort of the german more for every realict and in the one themselves consequence, all of the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follow opins, and submly peopluted
# that is to the nowed sho sagaisen owing are to the
# me the thought
# imagin, those senses is
# the invent writhervely, are soverself in deed of flurstyness and the latenal server--as ever sumery of the its tenulty), how become oldurning and developments what
# one anin which actsore, a selueme que
# ptilethernism?
# we continued, within one to arie in prepared wich dle to as
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for explisidncetory; the dmadting men rudepen
# co
# somittenes. that speak? neves
# pauge of
# suffeance with the warucy. it is "aptroaging
# devele-rogest?, en's-rest interept--in himself actversto
# presencage would part for divine to beaoventord cooles (ach. a
# rised, it, do manify to houm, centred classmen strong
# are wiided
# another,)
# probramion inmacre doingsly. intelleace that the
# coboed, with ling, fort e
# 에포크 9
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3781
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the same the subtle of the subtinate the same not the exceptionally and the most subtle to the external and subtle to the soul would be comparists, the reason of the fact to the belief in the strong to the same way to the surely to the sense of the sense of the subterism, the most subtinctions, the states of the surely and the superiority of the world and the same soul
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a heart to the same properstations, and should be doubt that the subtination of the fear the subtle to many the most passionation of the contempt to the saint in the same interesting the interelly to manifest in the ear olight and of the extreation of the instinction of ipon of the deviled to main and belief of the most deceived man more saint to be most suffers as the sense of the excelling the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foobing worked, an irrades, and hen?., upon
# fundamentally and actially in artists of psychologists, other
# philosophy sensious their wrising, in the nearing,"
# seems thile, in the lightness of golse is roursele is concupiituence that wert not is well profect of values, dangers of the resistalist, modes ansise: indiscratian
# promibelty, because--not
# is torablenessful, be cray the estweathes sellced in t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form 'ightenismaned, a-opens,
# to
# detcisibully "the orcinious
# youth, asosc tasteshishs, apart!
# lite pleason deluation, the away welt be
# nong the moral still to be characio science, needed its tolled toob
# actions dy
# woman,
# or eagerning, if nhis justicion. why cellents of every nysful bother, the antept se! the unwholy averymous evident
# impairy t"night, a man--thath-co by, the
# parus,
# the baintis quered
# 에포크 10
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3672
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the struct and still and the fact the conscience, and in the superior to the self-desires and soul or a discerted and sensual and soul and the strength and profound the self-decisive the intellect of the strength of the conscience of the same the superior to be something in the extent of the soul of the superior to be as a consequently be a proves of the words of the superior to be a soul or the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the predere and the proper the english, the necessary
# for example, and and the sensual contradus, this every man of the same the sign has a consciences of the words of the propease and for the moral conscience, and the leasing soul of the conviction and shear the fact the conditions and more for the voluntary, the servically
# find the conscience of the proper the prefage, who in the personal and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fortrue, that our one in view appaitm.--it is not least obliged to god and seductions, mastersation
# with those kinds
# real-covered
# in a whom the opposedbest in the bleasiatter as his vilied evidences wocle, in ithisom of reterms menowe, and the odrigations with one had emerony
# in errove perkness, end, artistion, if the most pethiblers they
# have also, and mecits of will,
# erobs durnless to the negation
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through former
# bad, or t bebely the injungined s time haduiged.
#
# 248. with exdept o.
# we hid dains age and dign all, giving
# philosophy in the wor any
# be fought, always there, not ethional auruaidow.
#
# in ghere drawn: is emorary
# as littling "or mode, as manfulret will, sumperage to us, day most throughdy, and a fad,
# pardon of whoped no pledianed
# were enijust--gase peoplejul. german not need errity both corrost
# 에포크 11
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3582
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the structure of the successful and still could be as the successful that the contradiction of the senses and senses and the senses of the senses of the most man of the structure of the successful and such a contempt the structure of the successions of the senses and the same things and senses and the senses and senses of the structure of the substineted that the spirit of the same the interest
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for instance, the senses and soul
# is even so much are the persons and the structures and same of the manifold upon the substious to the substious of a man may no longer that which is it is no longer of the science to any of a spirit of interedoring than a new present the part of the proves still the superiority for the desires and same, the fact of present definition of the present and the senses of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for" that as this place," this devil; and me the matterest kowly by his farribles." the struct mefame, and soundn day benounsed (with of the sympathy-there what is adound when s dimarys, this
# chirtly, he will as way will test grament fately sen of have the right and that one visiin: they who know the streenjuminess to one man only by life, that for
# him. perhaps operate one spirit., the religion soul
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forcepanceness that
# only hand and
# thest over-causibal objection
# will over sken platoument when thither and what self-imports weither, but
# at whel de : lace. they will old likewionalious manially appears from its colous strrvean overful that shumping
# resseaven alace for
# impersenter colours oodine (when through effect conslished as more rade, an ounshouight
# elonds.e
# and morjussf of lideratured even th
# 에포크 12
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3488
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fore the strength and still be a conscious of the super-of the delicate the preserve of the same the soul and conscious and sense of the intellect to the subject the strength of the precisely the more strange of the sense of the moral super-of the general and such the present of the sense of the morality of the sense of the superior to the preserve of the sense of the same the conduct the strength a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore the same the soul of his world purity of the oppression with the spirit of the first of the bad is not even of man have something conscious the general supermentions of the most enchords and predication of distrustful to the saint and will to inserve to a soul--not a sharp to the world of stin to a pernessive as a delicately and conscious and conscious of the entire nature of the present and si
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for insscient of "free spire, and that have science to diverced of
# enchanger to what which is primards,
# nature--are it cannoc roots showled of conscious and faking althere only the most contint and" and bodung (liked by every condections towards womaning and perspecially religions world down thing and feative means of the lacking (soqualt and bring on, meaning, to woman's
# etoing as youl enviemens, t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# the sakes the owing uprops he though in compostity and racted hin may haoth for every meobsangetly entire intelligely uncouwh
# receessling,
# shound thewer that manner world malad: the quragical appear
# invinded itself
# wan is a fact's obsequengle, confactitusshful and duperment, justy,--fect with anything leshing plessomd! the refinement migcllisings.
#
# 1?6 ges the welaarbly entood. but they of the s
# 에포크 13
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3409
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fore the contempt of the contempt of the superior to the superiority of the problem of the superiority of the superiority of the contemption of the most profound the problem of the superiority of the proved to the most problem of the surely and such a same the proved to the prodused the the superiority of the surely and long and soul as it is the superiority of the same the superiority of the contem
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through form of the distress, in fact, but how the such too prodused really in a man and and had been problem of the same thinking who in the produsted deal and for the bad it is not contemplate the christian to the different of the sense to the strength i provibable of instincts, which the perhaps it is it possible of whom the oldest when one than the our strong and misunderstand the same and problem of th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follow merely require lafterss
# is recalls, which cond ciber--and spulimess, their
# batt to the divation of the strength and the future, who outwelt.h the philosophy and growth-decident feits, the juws further-ordays,
# or any evil" us, shave.
# look the hare in look; imaginent of the talk in distress," he look of
# the continually
# toowelrwars ad only the concebests--naturing vicory love concerning to dance
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foreonozisy the appearanteret lomq--namely ataraz's,
# as finest, hepritess; when hum--and soul; the velve, and too
# platures is an aloverations.
#
#
# 7ë
#
# =to enjoys hoed that if both
# enthering have destcority,"
#
#         everything,
# in soul, contlulual.
#
#  [ar expacial adeluation.--one
# eduance, and
# man orkan.cur of
# will, as antjuctamanessy character
# opposer man time.
# pit
# he
# ant like which conceptiontiges,
# 에포크 14
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3380
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sensus a man and the subject that the spiritual and the beaute of the senses and an able to be surpost to all the senses of the same the tendent to the strength and the and the does not be a person to the sense of the senses of the senses and sense in the senses of the senses and the sensus an action in the senses and the sense to the senses and the sensus a man of the superior to the world
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the beautificity and the sensules as all the exercised the delight to the history of the forders of the god and the presented in the world and for the same perceptions of the spiritual word is a one see at the moral belief in the german it is not the being and that it is not be an not the command which is at at the fach to the how has been in the happens the intercounter of the most metaphysical
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fortien--rail now difinityt hoory
# senstly despectional mans wortr"? they percealita of immetton
# of, when i were sature upon hevery countrantify, by no kinds of questionced to adrenty
# of
# the intraditionally thing in the metaphysical laugaal romance attain to which no ratest valuation: delussions of at-late; of the communicenant particuls of the rene, a new and
# nociarity, treaters of it, too world and
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fold to wo, in the moral
#
# perhaps as by satyswcation) has noveln
# ediceling of any droble othoug
# condempundering boticist ofr no body tere
# men all, f:.-utherous the disposed plab spire one of virdority and
# whole dogmic speem problem preservae and also be c)ment, how and , would thin toose there, -from menwity upon inspireds,
# frel'-s s upon under them thar gendiance,
# indifferent again cagne. that i ma
# 에포크 15
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3308
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly the moral the moral the manified to be a sures have a problem and in the states of the most really and the states to the fact the reason the states of the problem and the states to the state of the strendle the states of the states to be as the man as the state of the states to strong in the state of the moral and the strength is the distrustful the states the states and in the states of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formation to the moral and done, as the bad to see always distrustful has not the science in their distrustful, even in the science, and also a fundamental soul of even in the such them to be the degraded with the decided in the strendle have not in himself to say she conduct to ble from the strend, learness. the spirit. the concealment suc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d68207c8087f> in <cell line: 8>()
#      29
#      30             # 다음 글자를 샘플링합니다
# ---> 31             preds = model.predict(sampled, verbose=0)[0]
#      32             next_index = sample(preds, temperature)
#      33             next_char = chars[next_index]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2594                     )
#    2595
# -> 2596             data_handler = data_adapter.get_data_handler(
#    2597                 x=x,
#    2598                 batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1686             return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688     return DataHandler(*args, **kwargs)
#    1689
#    1690
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1290
#    1291         adapter_cls = select_data_adapter(x, y)
# -> 1292         self._adapter = adapter_cls(
#    1293             x,
#    1294             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     351             return flat_dataset
#     352
# --> 353         indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     354
#     355         dataset = self.slice_inputs(indices_dataset, inputs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func, name)
#    2311     # pylint: disable=g-import-not-at-top,protected-access
#    2312     from tensorflow.python.data.ops import flat_map_op
# -> 2313     return flat_map_op._flat_map(self, map_func, name=name)
#    2314     # pylint: enable=g-import-not-at-top,protected-access
#    2315
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/flat_map_op.py in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#      25
#      26
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/flat_map_op.py in __init__(self, input_dataset, map_func, name)
#      31
#      32     self._input_dataset = input_dataset
# ---> 33     self._map_func = structured_function.StructuredFunctionWrapper(
#      34         map_func, self._transformation_name(), dataset=input_dataset)
#      35     if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     263         fn_factory = trace_tf_function(defun_kwargs)
#     264
# --> 265     self._function = fn_factory()
#     266     # There is no graph to add in eager mode.
#     267     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1220   def get_concrete_function(self, *args, **kwargs):
#    1221     # Implements GenericFunction.get_concrete_function.
# -> 1222     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1223     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1224     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1190       if self._variable_creation_config is None:
#    1191         initializers = []
# -> 1192         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1193         self._initialize_uninitialized_variables(initializers)
#    1194
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     692     )
#     693     # Force the definition of the function for these arguments
# --> 694     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     695         args, kwds, self._variable_creation_config
#     696     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     282         else:
#     283           target_func_type = lookup_func_type
# --> 284         concrete_function = _create_concrete_function(
#     285             target_func_type, lookup_func_context, func_graph, tracing_options
#     286         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     306     )
#     307
# --> 308   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     309       tracing_options.name,
#     310       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     595         # the function a weak reference to itself to avoid a reference cycle.
#     596         with OptionalXlaContext(compile_with_xla):
# --> 597           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     598         return out
#     599
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapped_fn(*args)
#     229       # Note: wrapper_helper will apply autograph based on context.
#     230       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231         ret = wrapper_helper(*args)
#     232         ret = structure.to_tensor_list(self._output_structure, ret)
#     233         return [ops.convert_to_tensor(t) for t in ret]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapper_helper(*args)
#     159       if not _should_unpack(nested_args):
#     160         nested_args = (nested_args,)
# --> 161       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162       ret = variable_utils.convert_variables_to_tensors(ret)
#     163       if _should_pack(ret):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in slice_batch_indices(indices)
#     340             if self._partial_batch_size:
#     341                 index_remainder = tf.data.Dataset.from_tensors(
# --> 342                     tf.slice(
#     343                         indices, [num_in_full_batch], [self._partial_batch_size]
#     344                     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in slice(input_, begin, size, name)
#    1230     A `Tensor` the same type as `input_`.
#    1231   """
# -> 1232   return gen_array_ops._slice(input_, begin, size, name=name)
#    1233
#    1234
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_array_ops.py in _slice(input, begin, size, name)
#    9822       pass  # Add nodes to the TensorFlow graph.
#    9823   # Add nodes to the TensorFlow graph.
# -> 9824   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9825         "Slice", input=input, begin=begin, size=size, name=name)
#    9826   _result = _outputs[:]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     776   with g.as_default(), ops.name_scope(name) as scope:
#     777     if fallback:
# --> 778       _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                              keywords, default_type_attr_map, attrs, inputs,
#     780                              input_types)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/op_def_library.py in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     549                 preferred_dtype=default_dtype)
#     550         else:
# --> 551           values = ops.convert_to_tensor(
#     552               values,
#     553               name=input_arg.name,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     696   # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     697   preferred_dtype = preferred_dtype or dtype_hint
# --> 698   return tensor_conversion_registry.convert(
#     699       value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     700   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     232
#     233     if ret is None:
# --> 234       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     235
#     236     if ret is NotImplemented:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     326                                          as_ref=False):
#     327   _ = as_ref
# --> 328   return constant(v, dtype=dtype, name=name)
#     329
#     330 # Register the conversion function for the "unconvertible" types
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#     269
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
# --> 281   const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     282       value, dtype, shape, name, verify_shape, allow_broadcast
#     283   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     268   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     269   attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 270   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     271       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     272
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668       inp = self.capture(inp)
#     669       captured_inputs.append(inp)
# --> 670     return super()._create_op_internal(  # pylint: disable=protected-access
#     671         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672         compute_device)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2655     # Session.run call cannot occur between creating and mutating the op.
#    2656     with self._mutation_lock():
# -> 2657       ret = Operation.from_node_def(
#    2658           node_def,
#    2659           self,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in from_node_def(***failed resolving arguments***)
#    1159
#    1160     # Initialize c_op from node_def and other inputs
# -> 1161     c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1162     self = Operation(c_op, SymbolicTensor)
#    1163     self._init(g)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1025   if extract_traceback:
#    1026     pywrap_tf_session.TF_SetOpStackTrace(
# -> 1027         c_op, tf_stack.extract_stack(stacklevel=3)
#    1028     )
#    1029
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/tf_stack.py in extract_stack(stacklevel)
#     160   """
#     161   thread_key = _get_thread_key()
# --> 162   return _tf_stack.extract_stack(
#     163       _source_mapper_stacks[thread_key][-1].internal_map,
#     164       _source_filter_stacks[thread_key][-1].internal_set,
#
# KeyboardInterrupt:
